# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\admin\appdata\roaming\python\python310\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python310\site-packages (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (4.32.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# <b>Visualizing the historical data </b>

# %%
df= pd.read_csv('internet_traffic_hist(1).csv') #reading the dataset
df.head()
# Out:
#       traffic  year
# 0  100.000000  2005
# 1  126.933755  2006
# 2  160.303757  2007
# 3  203.390603  2008
# 4  241.292566  2009

# %%
#ploting the year against traffic

plt.figure(figsize = (10,10))

x = df.year
y = df.traffic

plt.plot(x, y, linewidth = 2)
plt.plot(x, y, '*r', markersize = 10 )
plt.xlabel('Year')
plt.ylabel('Fixed Internet Traffic')

plt.rcParams.update({'font.size': 15})
plt.show()

# %% [markdown]
# <b>Application of Simple Linear Regression: First Order Polynomial</b>

# %%
plt.figure(figsize = (10,10))

order = 1

x = df.year
y = df.traffic

n, d = np.polyfit(x,y,order)

plt.plot(x, y, label = 'Historical Internet Traffic', linewidth = 2)
plt.plot(x, y,'*g', markersize = 10 )
plt.plot(x, n*x + d, label = 'Simple Linear Regression Line', linewidth = 2)

print ('The slope of line = {}.'.format(n))
print ('The y intercept = {}.'.format(d))
print ('The best fit simple linear regression line = {}x + {}.'.format(n,d))

plt.xlabel('Year')
plt.ylabel('Fixed Internet Traffic Volume')
plt.legend(loc = 'upper right')

plt.rcParams.update({'font.size': 15})
plt.show()
# Out:
# The slope of line = 79.52710966244514.
# The y intercept = -159457.12265833947.
# The best fit simple linear regression line = 79.52710966244514x + -159457.12265833947.

# %% [markdown]
# <b>Application of Linear Regression: Higher Order Polynomial</b>

# %%
models = []

for order in range(1,5):
   
    p = (np.poly1d(np.polyfit(x, y, order)))
    models.append(p)
    
plt.figure(figsize = (10,10))

for model in models[0:3]:
    plt.plot(x, model(x), label = 'order' + str(len(model)), linewidth = 3)

plt.plot(x, y, '*g', markersize = 10, label = 'Historical Internet Traffic', linewidth = 3)
plt.legend(loc = 'upper left')

plt.xlabel('Year')
plt.ylabel('Fixed Internet Traffic Volume')
plt.rcParams.update({'font.size': 15})

plt.show()

# %%
models = []       
errors_df = []  
mse_df = []

for order in range(1,4):

    p = (np.poly1d(np.polyfit(x, y, order)))
    models.append(p)
    
    e = np.abs(y-p(x))        
    mse = np.sum(e**2)/len(df) 
    
    errors_df.append(e)   
    mse_df.append(mse)

# %%
x = df.year
width = 0.2   #size of the bar

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

p1 = ax.bar( x, errors_df[0], width, color = 'b', label = 'Abs. error order 1 fit')
p2 = ax.bar( x + width, errors_df[1], width, color = 'r', label = 'Abs. error order 2 fit')
p3 = ax.bar( x + 2*width, errors_df[2], width, color = 'y', label = 'Abs. error order 3 fit')

# "Prettyfy" the bar graph
ax.set_xticks(x+2*width)
ax.set_xticklabels(x)
plt.legend(loc = 'upper left', fontsize =16)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

x = np.array([0,1,2])
width = 0.4  
p1 = ax.bar( x[0], mse_df[0], width, color = 'b', label = 'pred. error order 1 fit')
p2 = ax.bar( x[1], mse_df[1], width, color = 'r', label = 'pred. error order 2 fit')
p3 = ax.bar( x[2], mse_df[2], width, color = 'g', label = 'pred. error order 3 fit')
ax.set_xticks(x+width/2)
ax.set_xticklabels(['Poly.order1', 'Poly.order2', 'Poly.order3'], rotation=0)
plt.show()

# %% [markdown]
# <b>The above plot shows that the third polynomial order has the least amount of errors, and the error between the first and second orders is negligible. This suggests that the third polynomial is the best fit for the orders used</b>

# %%
order = 3

x = df.year.values      # x being the regressor value
y = df.traffic.values   # y being the regressand value

p_array = np.polyfit(x,y,order)

print(type(p_array), p_array)

p = np.poly1d(p_array)

print(type(p), p)

print('The value of the polynomial for x = 2020 is : {} '.format(p(2020)))

e = np.abs(y-p(x))
mse = np.sum(e**2)/len(x)

print('The polynomial parameters estimated are: {}'.format(p))
print('The errors for each value of x, with polynomial parameters estimated are: \n {}'.format(e))
print('The MSE is :{}'.format(mse))
# Out:
# <class 'numpy.ndarray'> [ 4.83129399e-01 -2.90500575e+03  5.82252080e+06 -3.89005383e+09]
# <class 'numpy.poly1d'>         3        2
# 0.4831 x - 2905 x + 5.823e+06 x - 3.89e+09
# The value of the polynomial for x = 2020 is : 2328.578447818756
# The polynomial parameters estimated are:         3        2
# 0.4831 x - 2905 x + 5.823e+06 x - 3.89e+09
# The errors for each value of x, with polynomial parameters estimated are:
#  [1.30743074 0.39125312 2.02722645 6.3298316  5.28394498 0.93069849
#  9.41692403 7.34009986 6.27729509 4.48133981 0.16291568]
# The MSE is :25.172186297832425

# %% [markdown]
# <b>Non-Linear Regression Model: Exponential Growth</b>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\admin\appdata\roaming\python\python310\site-packages (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scipy) (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.optimize import curve_fit

# %%
def my_exp_func(x, a, b):
    return a * (b ** x) 

x = np.arange(2016-2005)    
y = df.traffic.values  

p, cov = curve_fit(my_exp_func, x, y)
e = np.abs(y - my_exp_func(x, *p))
mse = np.sum(e**2)/len(df)

print('The exponential parameters estimated are: {}'.format(p))
print('The errors for each value of x, with exponential parameters estimated are: \n {}'.format(e))
print('The Mean Squared Error is :{}'.format(mse))

models.append(p)
# Out:
# The exponential parameters estimated are: [103.37820155   1.24678465]
# The errors for each value of x, with exponential parameters estimated are:
#  [ 3.37820155  1.95659915  0.39475818  3.03416206  8.50876843  2.65664491
#   8.32850918 11.70265938 12.59154088  0.47531783  7.10276483]
# The Mean Squared Error is :47.23616366678746

# %% [markdown]
# <b>Comparing Models</b>

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\roaming\python\python310\site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import r2_score

# %%
plt.figure(figsize = (10,10))

# Visualize polynomial models fit
for model in models[0:-1]:
    
    x = df.year.values      
    y = df.traffic.values   
    plt.plot(x, model(x), label = 'order ' + str(len(model)), linewidth = 3)

# Visualize exponenetial model fit
x = np.arange(2016-2005)    # the regressor is not the year in itself, but the number of years from 2005
plt.plot(df.year.values, my_exp_func(x, *models[-1]), label = 'Exp. non-linear regression', linewidth = 3)

plt.plot(df.year, df.traffic, '*r', markersize = 10, label='Historical Internet Traffic')
plt.legend(loc = 'upper left')

# Add axis labels
plt.xlabel('Year')
plt.ylabel('Fixed Internet Traffic Volume')
plt.show()

# %% [markdown]
# Visualise fit error for each year

# %%
x = df.year
width = 0.2   #size of the bar

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

p1 = ax.bar( x, errors_df[0], width, color = 'g', label = 'Abs. error order 1 fit')
p2 = ax.bar( x + width, errors_df[1], width, color = 'r', label = 'Abs. error order 2 fit')
p3 = ax.bar( x + 2*width, errors_df[2], width, color = 'y', label = 'Abs. error order 3 fit')


# "Prettyfy" the bar graph
ax.set_xticks(x+2*width)
ax.set_xticklabels(x)
plt.legend(loc = 'upper left', fontsize =10)
plt.show()

# %% [markdown]
# Visualise Mean Squares Error (MSE) for each model

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

x = np.array([0,1,2,3])
width = 0.4   #size of the bar

p1 = ax.bar( x[0], mse_df[0], width, color = 'g', label = 'pred. error order 1 fit')
p2 = ax.bar( x[1], mse_df[1], width, color = 'y', label = 'pred. error order 2 fit')
p3 = ax.bar( x[2], mse_df[2], width, color = 'r', label = 'pred. error order 3 fit')


ax.set_xticks(x+width/2)
ax.set_xticklabels(['Poly. order 1', 'Poly. order 2', 'Poly. order 3', 'Exp. model' ], rotation=0)
plt.show()

# %% [markdown]
# <b>From the plot, the third order polynomial fits better the traffic measurements in the observed range</b>

# %% [markdown]
# <h> Visualizing for the future internet traffic</h>

# %%
df1= pd.read_csv('internet_traffic_histtwo.csv') #reading the dataset
df1.head()
# Out:
#       traffic  year
# 0  100.000000  2005
# 1  126.933755  2006
# 2  160.303757  2007
# 3  203.390603  2008
# 4  241.292566  2009

# %%
df2 = pd.concat([df, df1]).reset_index()
df2.drop('index', axis=1, inplace=True)
df2 = df.drop_duplicates() #removing dulpicates
df2.head(20)
# Out:
#        traffic  year
# 0   100.000000  2005
# 1   126.933755  2006
# 2   160.303757  2007
# 3   203.390603  2008
# 4   241.292566  2009
# 5   308.791823  2010
# 6   379.980659  2011
# 7   495.840568  2012
# 8   616.207252  2013
# 9   752.103483  2014
# 10  931.200929  2015

# %%
plt.figure(figsize = (10,10))

errors_all = []
mse_all = []

for model in models[0:-1]:
    
    # Visualize polynomial model fit
    x = df2.year.values      
    y = df2.traffic.values   
    plt.plot(x, model(x), label = 'order ' + str(len(model)), linewidth = 3)
    
    # error and mse for polynomial models
    pred_y = model(x)
    e = np.abs(y - pred_y)
    errors_all.append(e)   #Store the absolute errors
    mse_all.append(np.sum(e**2)/len(df)) # Store the mse
    
    
# Visualize exponential model fit
x = np.arange(2021-2005)    # the regressor is not the year in itself, but the number of years from 2005
pred_y = my_exp_func(x, *models[-1])
plt.plot(df2.year, df.traffic, '*k', markersize = 10, label='Projected Internet Traffic')
plt.legend(loc = 'upper left')

# Add axis labels
plt.xlabel('Year')
plt.ylabel('Fixed Internet Traffic Volume')
plt.axis([2004,2021, -300, 3500])
plt.show()
